# %%
from gensim.models import word2vec
import gensim.models
from sklearn.decomposition import PCA
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from numba import jit# 加速套件
import glob
import os
import statistics as stat
from scipy import stats
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import xlsxwriter
import numpy as np
import numpy as ndarray
from gensim.models import word2vec
#from gensim.models import Word2vec
from gensim import models
import logging
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
import jieba
from gensim.test.utils import datapath
import re

# %%
# 載入bin檔
wv_from_bin = KeyedVectors.load_word2vec_format(datapath(r'C:\Users\Big data\Desktop\class\funcardproject\word2vec_model\news\測試100win20cbow1.bin'), binary=True)

# %%
#載入整篇文章
articles = pd.read_excel(r"C:\Users\Big data\Desktop\class\funcardproject\data\文章\新聞\article_news.xlsx")

# %%
def get_claen_data(article):
    #清理
    #轉DataFrame
    news=pd.DataFrame(article,columns=['content'])
    #斷詞
    df1=斷詞(news)
    #清乾淨
    news = 整理(df1)
    # 轉list
    wordlist = [x for x in news.split(' ')]
    return(wordlist)

# %%
#去除不在字典的詞
def drop(wordlist):
    index2word_set = list(wv_from_bin.index2word)
    for word in wordlist:
        wordlists=[]
        if word in index2word_set:
            wordlists = wordlist.append(word)
    return(wordlist)

# %%
def get_article_vector(wordlist):
    #取每篇文章平均向量
    # x=np.matrix(wv_from_bin[word])安安?
    for article in articles:
        len_wordlist = len(wordlist)
        article_vector_matrix=0

        for word in wordlist:
            try:
                x=np.matrix(wv_from_bin[word])
                article_vector_matrix+=x
                article_vector_matrix = article_vector_matrix/len_wordlist
            except:
                pass
    #matrix轉list
    示範 = np.array(article_vector_matrix)#np.ndarray()
    哭阿=示範.tolist()#list
    #寫入datafram
    article['article_vector_matrix']=哭阿

    return(article)

# %%
articles.loc[2:2,["content"]]
# Out:
#                                              content
# 2  雙11網購主打賓士車　交易攻略回饋16.8萬元\n\n\n　　雙11購物節戰火激烈，網購平台...

# %%
articles
# Out:
#    Unnamed: 0 Unnamed: 0.1                                            content  \
# 0           0            0  國內刷卡回饋重洗牌　無腦刷排行榜大車拼\n\n\n　　下半年信用卡市場「流血搶市」，多家銀行...
# 0           0            1  直擊雙11電商AI倉儲　下單到出貨僅10分鐘\n\n\n　　雙11狂熱訂單爆量，電商平台拼「...
# 0           0            2  雙11網購主打賓士車　交易攻略回饋16.8萬元\n\n\n　　雙11購物節戰火激烈，網購平台...
# 0           0            3  刷信用卡繳納地價稅　24家銀行免收手續費\n\n\n　　今(2019)年最後一項稅款地價稅，...
# 0           0            4  4張行動支付聯名卡對決　街口卡力尬Pi拍錢包\n\n\n　　隨著街口聯名卡上市，炒熱行動支付...
# 0           0            5  零售4大錢包各顯神威　支付累點還能存零錢\n\n\n　　在行動支付的浪潮下，傳統的零售通路展...
# 0           0            6  前8月刷卡量衝2兆元　玉山包辦第3季發卡王\n\n\n　　歷經6月報稅入帳的高峰後，今(20...
# 0   [-0.0003745066933333874, -0.003859373973682522...
# 0   [-3.212874798919074e-05, -0.001002146513201296...
# 0   [-0.00010502051736693829, -0.00095632800366729...
# 0   [-0.000647861510515213, -0.0018272802699357271...
# 0   [0.0019443725468590856, -0.003114804858341813,...
# 0   [0.0023627288173884153, -0.002477934816852212,...
# 0   [-0.00044692211668007076, -0.00169097131583839...
# 0   [-0.00042662135092541575, -0.00161396956536918...
# 0   [-0.0006714491173624992, 1.4347158867167309e-0...
# 0   [-0.00029141371487639844, -0.00110158976167440...
# 0   [-0.000343004590831697, -0.0011864813277497888...
# 0   [-0.00043653586180880666, -0.00165157346054911...
# 0   [-0.0004183389828540385, -0.001568892388604581...
# 0   [0.00017753652355168015, -0.000216228145291097...
# 0   [-0.0010794311529025435, -0.001958893379196524...
# 0   [0.0004945550463162363, 0.00016654268256388605...
# 0   [0.0011402963427826762, -0.0001155710124294273...
# 0   [0.0005359649658203125, -0.0005512512288987637...
# 0   [-0.00035877834307029843, -0.00049876287812367...
# 0   [-0.00011526169691933319, -0.00113516068086028...
# 0   [0.0008152012014761567, -0.0006867680931463838...
# 0   [4.6830497012706473e-05, -0.000163882767083123...
# 0   [-0.0003934263368137181, -0.001488119596615433...
#
# [5594 rows x 4 columns]

# %%
#隨意輸入文字
input_words="真愛只是遲到不是不會到"
#轉DataFrame
# input_words=pd.DataFrame(input_words,columns=['content'])
#斷詞
wordlist=jieba.lcut(input_words,cut_all=False)
# df1=斷詞(input_words)
#清乾淨
# news = 整理(cut)
# 吐出來
# output_words = input_words['seg'][0]
# output_words = output_words.split(' ')
wordlist
# Out:
# ['真愛', '只是', '遲到', '不是', '不會', '到']

# %%
index2word_set = list(wv_from_bin.index2word)
index2word_set
# Out:
# ['的',
#  '在',
#  '是',
#  '有',
#  '信用卡',
#  '也',
#  '了',
#  '就',
#  '月',
#  '都',
#  '到',
#  '銀行',
#  '年',
#  '他',
#  '1',
#  '後',
#  '等',
#  '我',
#  '為',
#  '元',
#  '來',
#  '要',
#  '不',
#  '3',
#  '人',
#  '說',
#  '但',
#  '新聞',
#  '被',
#  '2',
#  '和',
#  '與',
#  '會',
#  '於',
#  '上',
#  '可以',
#  '讓',
#  '贊助',
#  '刷卡',
#  '消費',
#  '你',
#  '對',
#  '日',
#  '使用',
#  '中',
#  '沒',
#  '5',
#  '好',
#  '10',
#  '能',
#  '民眾',
#  '因為',
#  '個',
#  '公司',
#  '萬',
#  '。',
#  '台灣',
#  '11',
#  '就是',
#  '可',
#  '我們',
#  '更',
#  '多',
#  '買',
#  '4',
#  '從',
#  '錢',
#  '表示',
#  '卻',
#  '跟',
#  '再',
#  '越',
#  '或',
#  '以',
#  '最',
#  '她',
#  '回饋',
#  '支付',
#  '自己',
#  '而',
#  '用',
#  '現金',
#  '活動',
#  '把',
#  '提供',
#  '優惠',
#  '才',
#  '消費者',
#  '6',
#  '手機',
#  '刷',
#  '警方',
#  '不過',
#  '想',
#  '目前',
#  '很',
#  '這',
#  '發現',
#  '服務',
#  '去',
#  '一個',
#  '7',
#  '該',
#  '推出',
#  '萬元',
#  '8',
#  '這個',
#  '可能',
#  '業者',
#  '您',
#  '卡',
#  '得',
#  '9',
#  '還有',
#  '今年',
#  'LINE',
#  '又',
#  '及',
#  '他們',
#  '金額',
#  '如果',
#  '記者',
#  '已經',
#  '帶',
#  '只要',
#  '時',
#  '網路',
#  '沒有',
#  '20',
#  '資料',
#  'Pay',
#  '看',
#  '金融',
#  '現在',
#  '新',
#  '市場',
#  '高',
#  '2019',
#  '商品',
#  '優質',
#  '文章',
#  '日本',
#  '還是',
#  '000',
#  '大',
#  '嫌犯',
#  '交易',
#  '長',
#  '篇文章',
#  '送',
#  '超過',
#  '加入',
#  '拿',
#  'iPhone',
#  '比',
#  '集團',
#  '合作',
#  '行動支付',
#  '甚至',
#  '台北',
#  '金',
#  'TVBS',
#  '陳',
#  '內',
#  '最高',
#  '前',
#  '透過',
#  '億元',
#  '男子',
#  '時間',
#  '百貨',
#  '歲',
#  '較',
#  '中心',
#  '已',
#  '購物',
#  '旅遊',
#  '看到',
#  '除了',
#  '下',
#  '由',
#  '這樣',
#  '客戶',
#  '方式',
#  '回家',
#  '按',
#  '之',
#  '經濟',
#  '做',
#  '只',
#  '12',
#  '直接',
#  '平台',
#  '支持',
#  '問題',
#  '因此',
#  '30',
#  '且',
#  '約',
#  '美國',
#  '中獎',
#  '以及',
#  '登入',
#  '至',
#  '知道',
#  '成',
#  '著',
#  '其實',
#  '開始',
#  '盜刷',
#  '其他',
#  '獲得',
#  '包括',
#  'APP',
#  '超商',
#  '台',
#  '向',
#  '所以',
#  '機率',
#  '心中',
#  '其中',
#  '搶',
#  '不是',
#  '金幣',
#  '一名',
#  '話',
#  '成長',
#  '或是',
#  '一',
#  '好友',
#  '多天',
#  '帳戶',
#  '....',
#  '第',
#  '仟元',
#  '另外',
#  '以活',
#  '動金幣',
#  '狀況',
#  '什麼',
#  '卡片',
#  '！',
#  '申請',
#  '這些',
#  '未來',
#  '走',
#  '話題',
#  '達',
#  '付款',
#  '增加',
#  '希望',
#  '今天',
#  '嗎',
#  '金管會',
#  '去年',
#  '那',
#  '黃',
#  '只是',
#  '跟上',
#  '還',
#  '小姐',
#  '點',
#  '手續費',
#  '像',
#  '根據',
#  '快點',
#  '100',
#  '時事',
#  'HOT',
#  '像是',
#  '時候',
#  'Apple',
#  '很多',
#  '要求',
#  '億',
#  '台幣',
#  '現金回饋',
#  '大陸',
#  '詐騙',
#  '張',
#  '不少',
#  '一般',
#  '它',
#  '即可',
#  '期間',
#  '同時',
#  '而且',
#  '工作',
#  '以上',
#  '調查',
#  '騙',
#  '部分',
#  '認為',
#  '怎麼',
#  '找',
#  '被害人',
#  '聯名卡',
#  '系統',
#  '吃',
#  '電影',
#  '功能',
#  '國內',
#  '帳單',
#  '只有',
#  '利用',
#  '請',
#  '真的',
#  '全球',
#  '女子',
#  '不會',
#  '生活',
#  '製',
#  '出',
#  '身分',
#  '指出',
#  '不用',
#  '無',
#  '不同',
#  '200',
#  '台北市',
#  '完成',
#  '啊',
#  '需要',
#  '站',
#  '若',
#  '電話',
#  '美元',
#  '保險',
#  '飯店',
#  '聯合',
#  '加上',
#  '但是',
#  '折',
#  '方便',
#  '東西',
#  '賺',
#  '科技',
#  '雖然',
#  '繳稅',
#  '不到',
#  '政府',
#  '免費',
#  '一次',
#  '家',
#  '一樣',
#  '進行',
#  '加油',
#  '購買',
#  '香港',
#  '不能',
#  '海外',
#  '想到',
#  '悠遊卡',
#  '打',
#  '有人',
#  '機場',
#  '500',
#  '21',
#  '所有',
#  '選擇',
#  '出現',
#  '天',
#  '分享',
#  '店家',
#  '數位',
#  '％',
#  '綁定',
#  '15',
#  '相關',
#  '馬',
#  '成為',
#  '旅客',
#  '滿',
#  '起',
#  '第一',
#  '查詢',
#  '隨時',
#  '網站',
#  '50',
#  '機票',
#  '發生',
#  '這是',
#  '蘋果',
#  '高達',
#  '結帳',
#  '品牌',
#  '相當',
#  '賣',
#  '指定',
#  '必須',
#  '先',
#  '利率',
#  '先生',
#  '平均',
#  '大家',
#  '收到',
#  '點數',
#  '企業',
#  '人員',
#  '最大',
#  '發卡',
#  '機會',
#  '名',
#  '卡友',
#  '一定',
#  '辦',
#  '影響',
#  '機構',
#  '錢包',
#  '安全',
#  '覺得',
#  '通路',
#  '今',
#  '繳費',
#  '通知',
#  '多元',
#  '日報',
#  '月底',
#  '商店',
#  '分期',
#  '機',
#  '盜',
#  '外',
#  '原本',
#  '小',
#  '用戶',
#  '竟然',
#  '日前',
#  '每個',
#  '上限',
#  '無法',
#  '千元',
#  '倍',
#  '非常',
#  '處',
#  '網友',
#  '主要',
#  '持卡人',
#  '廣告',
#  '結果',
#  '每',
#  '累積',
#  '資訊',
#  '副',
#  '原來',
#  '次',
#  '客人',
#  '需求',
#  '網購',
#  '將',
#  '統計',
#  '發展',
#  '餐廳',
#  '自動',
#  '紅利',
#  '只能',
#  '不要',
#  '吸引',
#  '管理',
#  '才能',
#  '曾',
#  '成功',
#  '跑',
#  '提醒',
#  '幫',
#  '這種',
#  '電子',
#  '出國',
#  '這名',
#  '輕',
#  '一起',
#  '宣布',
#  '一張',
#  '所',
#  '朋友',
#  '國泰世華',
#  '一些',
#  '特別',
#  '地',
#  '行動',
#  '當時',
#  '申辦',
#  '按鈕',
#  '國際',
#  '高點',
#  '應該',
#  '枚',
#  '仍',
#  '加油站',
#  '發行',
#  '信用',
#  '高鐵',
#  '網點',
#  '電子支付',
#  'facebook',
#  '間',
#  '規定',
#  '老',
#  '點按',
#  '小時',
#  '當您',
#  '至會員',
#  '網及',
#  '開放',
#  '不僅',
#  'Uber',
#  '董事',
#  '處理',
#  '自',
#  '銀',
#  '注意',
#  '300',
#  '中國信託',
#  '是否',
#  '計程車',
#  '搭',
#  '貸款',
#  '並',
#  '發票',
#  '費用',
#  '進',
#  '過去',
#  '兌換',
#  '扣款',
#  '這麼',
#  '國外',
#  '鬆',
#  '加碼',
#  '萬張',
#  '顯示',
#  '圖',
#  '行',
#  '開',
#  '價格',
#  '目標',
#  '捷運',
#  '比較',
#  '現場',
#  '至於',
#  '產品',
#  '接受',
#  '折扣',
#  '業務',
#  '專家',
#  '實體',
#  '停車',
#  '包包',
#  '持續',
#  '根本',
#  '想要',
#  '店員',
#  '一年',
#  '一下',
#  '至少',
#  '期',
#  '強調',
#  '一家',
#  '重要',
#  '拍',
#  '女',
#  '花',
#  '年底',
#  '全台',
#  '店',
#  '事',
#  '偷',
#  '近',
#  '便宜',
#  '電腦',
#  '轉帳',
#  '總',
#  '還能',
#  '對方',
#  '13',
#  '24',
#  '投資',
#  '準備',
#  '密碼',
#  '收入',
#  '會員',
#  '商家',
#  '方案',
#  '金融卡',
#  '即',
#  '單筆',
#  '最近',
#  '最低',
#  '還要',
#  '好康',
#  '分析',
#  '越來',
#  '客服',
#  '闆',
#  '航空',
#  '40',
#  '一直',
#  '線',
#  '費',
#  'ATM',
#  '報導',
#  '桃園',
#  '0',
#  '包含',
#  '未',
#  '多少',
#  '分鐘',
#  '享有',
#  '任何',
#  '有些',
#  '幣',
#  '整合',
#  '針對',
#  '18',
#  '存款',
#  '人民',
#  '提升',
#  '2018',
#  '明年',
#  '造成',
#  '限制',
#  '賣場',
#  '機車',
#  '設計',
#  '情況',
#  '竊',
#  '顧客',
#  '監視器',
#  '正式',
#  '預計',
#  '變成',
#  '如',
#  '路上',
#  '手',
#  '快速',
#  '結合',
#  '儲值',
#  '台新',
#  '地方',
#  '獨家',
#  '占',
#  '25',
#  '智慧',
#  '完全',
#  '大概',
#  '使用者',
#  '住',
#  '取消',
#  '詐',
#  '擁有',
#  '取得',
#  '回',
#  '啦',
#  '同樣',
#  '擔心',
#  '提高',
#  '【',
#  '】',
#  '立刻',
#  '帳號',
#  '拿到',
#  '進入',
#  '許多',
#  '確認',
#  '體驗',
#  '另',
#  '快',
#  '權益',
#  '身上',
#  '習慣',
#  '率',
#  '每月',
#  '玉山銀',
#  '族群',
#  '每天',
#  '恐怕',
#  '容易',
#  '美食',
#  '這次',
#  '打造',
#  '工具',
#  '提出',
#  '商機',
#  '咖啡',
#  '單',
#  '紀錄',
#  '高雄',
#  '世界',
#  '不斷',
#  '聽',
#  '新北市',
#  '總經理',
#  '幾乎',
#  '們',
#  '了解',
#  '省',
#  '靠',
#  '投訴',
#  '一步',
#  '係',
#  '乘客',
#  '總統',
#  '歹徒',
#  '照片',
#  '富邦',
#  '通通',
#  '簡訊',
#  '下午',
#  '旅行社',
#  '運動',
#  '就要',
#  '知名',
#  '拿出',
#  '此外',
#  '書',
#  '避免',
#  '搭配',
#  '遭到',
#  '每年',
#  '建議',
#  '之前',
#  '一卡通',
#  '低',
#  '公布',
#  '臉書',
#  '價值',
#  '社會',
#  '員工',
#  '成本',
#  '這裡',
#  '決定',
#  '收',
#  '則是',
#  '線上',
#  '喜歡',
#  '風險',
#  '額度',
#  '男',
#  '呢',
#  '殺',
#  '利息',
#  '件',
#  '中央社',
#  '遭',
#  '犯案',
#  '各家',
#  '復',
#  '吧',
#  '各',
#  '電商',
#  '受害',
#  '一天',
#  '司機',
#  '損失',
#  '即日起',
#  '經過',
#  '過程',
#  '鎖定',
#  '一點',
#  '全部',
#  '包',
#  '手法',
#  '交通',
#  '不但',
#  '基金',
#  '可是',
#  '裡面',
#  '內容',
#  '方面',
#  '這張',
#  '票',
#  '台新銀行',
#  '便利',
#  '找到',
#  '減少',
#  '家銀行',
#  '年前',
#  'App',
#  '16',
#  '千',
#  '事件',
#  '機器',
#  '技術',
#  '當然',
#  '玉山',
#  '傳統',
#  '計畫',
#  '項',
#  '分別',
#  '單位',
#  '能夠',
#  '中國',
#  '案件',
#  '辦理',
#  '祭出',
#  '提款',
#  '14',
#  '到底',
#  '如何',
#  '國家',
#  '個資',
#  '證件',
#  '寫',
#  '自行',
#  '學生',
#  '掉',
#  '配合',
#  '最新',
#  '專屬',
#  '辦法',
#  '地區',
#  '例如',
#  '滿額',
#  '員',
#  '主管',
#  '小心',
#  '◎',
#  '福利',
#  '簡單',
#  '事情',
#  '保障',
#  '清楚',
#  '畫面',
#  '皮包',
#  '叫',
#  '連續',
#  '媒體',
#  '誰',
#  '註',
#  '姓',
#  '經營',
#  '起來',
#  '或者',
#  '分',
#  '麵',
#  '逮捕',
#  '17',
#  '1000',
#  '儘',
#  '第二',
#  '受到',
#  '太',
#  '付費',
#  '複',
#  '放在',
#  '各種',
#  '輸入',
#  '軟體',
#  '3%',
#  '尤其',
#  '怕',
#  '1%',
#  'QR',
#  '5%',
#  '折抵',
#  '之外',
#  '不管',
#  '模式',
#  '享受',
#  '機制',
#  '美金',
#  '實際',
#  '綁',
#  '週年慶',
#  '60',
#  '觀光',
#  '全面',
#  '31',
#  '抽',
#  '一位',
#  '拚',
#  '玩',
#  '銀行業者',
#  '花旗',
#  '因',
#  '遊戲',
#  '600',
#  '應',
#  '影片',
#  '全',
#  '難',
#  '最好',
#  '名牌',
#  '旗下',
#  '應用',
#  '虛擬',
#  '10%',
#  '管',
#  '女性',
#  '新高',
#  '皮夾',
#  '原因',
#  '推動',
#  '下載',
#  '立委',
#  '保費',
#  '排隊',
#  '證明',
#  '旅行',
#  '員警',
#  '上路',
#  '那個',
#  '以下',
#  '汽車',
#  '推',
#  '家庭',
#  '自助',
#  '機關',
#  '限量',
#  '2%',
#  '戶',
#  '出來',
#  '據',
#  '將近',
#  '趨勢',
#  '自由',
#  '號碼',
#  '回應',
#  '得到',
#  '看看',
#  '街口',
#  '電子票證',
#  '超市',
#  '行程',
#  '醫院',
#  '簽帳',
#  '連',
#  '就算',
#  '卡號',
#  '搭乘',
#  '完',
#  '負擔',
#  '遊客',
#  '駭客',
#  '收取',
#  '而是',
#  '繳款',
#  '接到',
#  '幫忙',
#  '繼續',
#  '離開',
#  '上線',
#  '感應',
#  '有民眾',
#  '政策',
#  '前往',
#  '懷疑',
#  '報案',
#  '家人',
#  '通常',
#  '繳納',
#  '2020',
#  '協助',
#  '組織',
#  '日起',
#  '財政部',
#  '韓國',
#  '假',
#  '★',
#  '是不是',
#  '這位',
#  '裝置',
#  '貨幣',
#  '競爭',
#  '打電話',
#  '死者',
#  '操作',
#  '購票',
#  '辦卡',
#  '禮券',
#  '授權',
#  '22',
#  '萬人',
#  '上網',
#  '享',
#  '紅利點數',
#  '媽媽',
#  '行銷',
#  '城市',
#  '整個',
#  '消費滿',
#  '門市',
#  '還在',
#  '住宿',
#  '偽造',
#  '左右',
#  'vs',
#  'Card',
#  '少',
#  '錶',
#  '改變',
#  '塊',
#  '新加坡',
#  '電視',
#  '報警',
#  '代表',
#  '掌握',
#  '全都',
#  '兒子',
#  '蹤',
#  '上海',
#  ...]

# %%
# 斷詞套件
def 斷詞(news):
    df1=news
    df1['seg']=None
    df1['word_freq']=None
    n=len(news)
    alltext=[]
    stopset=set()
    stop2=['/n','']
    with open('C:\\Users\\Big data\\Desktop\\字詞貼標\\DB104-master\\stop.txt','r',encoding='ISO-8859-1') as s:
        for line in s:
            stopset.add(line.strip('\n'))
    jieba.load_userdict('C:\\Users\\Big data\\Desktop\\字詞貼標\\DB104-master\\userdict.txt')
    for i in range(n):
        seg=''
        wf={}
        text= str(df1.loc[i]['content'])
        cut=jieba.cut(text,cut_all=False)
        for j in cut:
            if j not in stopset:
                seg +=j+' '
                seg = seg.replace("\n",'')
        df1['seg'][i]=seg
        for w in seg.split(' '):
            if w not in wf:
                wf[w]=1
            else:
                wf[w]+=1
        word_list=[(k,wf[k]) for k in wf if k not in stop2 ]
        word_list.sort(key=lambda a :a[1],reverse=True)
        df1['word_freq'][i]=word_list
    return(df1)



# 斷詞整理(去除標點符號)
def 整理(df1):
    datanews = df1["seg"]
    # 轉list
    train_data = np.array(datanews)#np.ndarray()
    datanews=train_data.tolist()#list
    df1=''
    for datanew in datanews:
        df1+=str(datanew)+'\n'
    df1=df1.replace('[','').replace('\'','').replace('「 ','').replace('」 ','').replace('」 ','').replace('、 ','').replace('： ','')
    df1=df1.replace('《 ','').replace('》 ','').replace('） ','').replace('( ','').replace('／ ','').replace('， ','')
    df1=df1.replace('╱ ','').replace('！ ','').replace('？ ','').replace('（ ','').replace('。 ','').replace('； ','').replace('… ','')
    df1=df1.replace(']','').replace(' :','').replace('\u3000','').replace('\n','')
    df2=df1
    for i in range(len(df2)):
        df1=' '.join(df2.split())
    return(df1)
