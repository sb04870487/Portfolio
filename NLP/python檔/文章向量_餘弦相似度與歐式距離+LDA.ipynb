# %%
from gensim.models import word2vec
import gensim.models
from sklearn.decomposition import PCA
import matplotlib
import matplotlib.pyplot as plt
from numba import jit# 加速套件
import glob
import os
import statistics as stat
from scipy import stats
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import xlsxwriter
import numpy as np
import numpy as ndarray
from gensim.models import word2vec
#from gensim.models import Word2vec
from gensim import models
import logging
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
import jieba
from gensim.test.utils import datapath

# %% [markdown]
# # 以下是順序

# %%
"""
1.載入檔案,這個檔案是每篇文章的內文與平均向量,拿出平均向量那欄,存到articles_matrix裡面
2.載入bin檔,這個檔案是訓練好的bin檔,裡面有每個詞的向量
測試開始
3.輸入文字:def 請輸入文字(input_words)把輸入的文章斷詞成字
4.獲取輸入詞的平均向量:def get_article_avgvector(wordlist):把斷完詞的單字利用先前載入的bin檔依序變成向量,加總後再取平均
於是現在有了輸入的文章平均詞向量,接著,只要與原本的文章向量做比對,就可以找到最相近的文章
5.餘弦相似度:def cos_sim(vector_a, vector_b):這個函數把輸入的向量跟5000篇新聞逐一比對餘弦相似度
6.比對:def 餘閒相似度找文章(input_words):這個函數把5.比對的結果存起來,再找出最相近的一篇列出來
"""
# Out:
# '\n1.載入檔案,這個檔案是每篇文章的內文與平均向量,拿出平均向量那欄,存到articles_matrix裡面\n2.載入bin檔,這個檔案是訓練好的bin檔,裡面有每個詞的向量\n測試開始\n3.輸入文字:def 請輸入文字(input_words)把輸入的文章斷詞成字\n4.獲取輸入詞的平均向量:def get_article_avgvector(wordlist):把斷完詞的單字利用先前載入的bin檔依序變成向量,加總後再取平均\n於是現在有了輸入的文章平均詞向量,接著,只要與原本的文章向量做比對,就可以找到最相近的文章\n5.餘弦相似度:def cos_sim(vector_a, vector_b):這個函數把輸入的向量跟5000篇新聞逐一比對餘弦相似度\n6.比對:def 餘閒相似度找文章(input_words):這個函數把5.比對的結果存起來,再找出最相近的一篇列出來\n'

# %%
#1.載入文章檔案
articles = pd.read_excel(r"C:\Users\Big data\Desktop\class\funcardproject\LDA\LDA_向量_20群.xlsx")
articles
# Out:
#       Unnamed: 0   No.                                            content  \
# 0              0     0  國內刷卡回饋重洗牌　無腦刷排行榜大車拼\n\n\n　　下半年信用卡市場「流血搶市」，多家銀行...
# 1              1     1  直擊雙11電商AI倉儲　下單到出貨僅10分鐘\n\n\n　　雙11狂熱訂單爆量，電商平台拼「...
# 2              2     2  雙11網購主打賓士車　交易攻略回饋16.8萬元\n\n\n　　雙11購物節戰火激烈，網購平台...
# 3              3     3  刷信用卡繳納地價稅　24家銀行免收手續費\n\n\n　　今(2019)年最後一項稅款地價稅，...
# 4              4     4  4張行動支付聯名卡對決　街口卡力尬Pi拍錢包\n\n\n　　隨著街口聯名卡上市，炒熱行動支付...
# 5              5     5  零售4大錢包各顯神威　支付累點還能存零錢\n\n\n　　在行動支付的浪潮下，傳統的零售通路展...
# 6              6     6  前8月刷卡量衝2兆元　玉山包辦第3季發卡王\n\n\n　　歷經6月報稅入帳的高峰後，今(20...
# 7              7     7  刷信用卡如打怪衝等　累積紅利刺激養卡潮\n\n\n　　信用卡市場戰火連天，持卡人「逐回饋而刷...
# 8              8     8  電信聯名卡升級激戰　購機回饋分期0利率\n\n\n　　iPhone新機上市引爆電信續約與換約...
# 9              9     9  全聯多元支付大解放　實體信用卡封印解除\n\n\n　　全聯福利中心強力推出「PX Pay」行...
# 10            10    10  第4季信用卡加油優惠　台塑卡折降4.2元超神\n\n\n　　9月中旬沙烏地阿拉伯原油設施遭到...
# 11            11    11  新光三越週年慶攻略　3大絕招衝高回饋率\n\n\n　　新光三越週年慶明(3)天開跑，姊妹們拿...
# 12            12    12  華航卡改嫁中國信託　台新銀低調迎娶街口\n\n\n　　信用卡戰局瞬息萬變，中華航空聯名卡傳出...
# 13            13    13  手機摔傷好險有保險　5大電信方案懶人包\n\n\n\r\n\t　　iPhone 11系列新機...
# 14            14    14  7月玉山卡「熊」利害　8月國泰世華超前200億\n\n\n\r\n\t　　信用卡賽事下半場一...
# 15            15    15  3大網購聯名卡大廝殺　比回饋比效期便利性\n\n\n\r\n\t　　國內3大電商平台皆已發行...
# 16            16    16  揭開信用卡高回饋秘密　銀行打得3大如意算盤\n\n\n\r\n\t　　國內信用卡回饋不斷飆升...
# 17            17    17  6月中國信託成功壓哨　7月台新慘遭玉山熊吻\n\n\n\r\n\t　　政府積極推動非現金支付...
# 18            18    18  數位帳戶信用卡點名　KOKO回饋9%大戶給8%\n\n\n\r\n\t　　搶攻網路原生族群，...
# 19            19    19  4大超商信用卡攻略　U Bear回饋8%新神卡\n\n\n\r\n\t　　「便利商店」是民眾...
# 20            20    20  3大LINE Points卡點名　賴點卡2%回饋最大方\n\n\n　　信用卡回饋除了現金回饋...
# 21            21    21  超市購物優惠總整理　行動支付回饋最大方\n\n\n\r\n\t　　居家鄰近的「超市」，已是零...
# 22            22    22  現金回饋須注意7大事　打破高趴數字迷思\n\n\n\r\n\t　　「現金回饋」為近年信用卡顯...
# 23            23    23  刷卡繳稅件數5年新低　平均單卡首破10萬大關\n\n\n\r\n\t　　今(108)年綜所稅...
# 24            24    24  計程車多元支付集合　感應掃碼不須掏現金\n\n\n\r\n\t　　交通部拍板定案「Uber條...
# 25            25    25  6大速食店支付比一比　麥當勞能刷能嗶稱霸\n\n\n\r\n\t　　在多元支付的風潮下，連鎖...
# 26            26    26  9大分期卡集合總點名　0利率再加送現金回饋\n\n\n\r\n\t　　不論是購物旅遊、或是繳...
# 27            27    27  台灣Pay種類大解密　信用卡金融卡都不同\n\n\n\r\n\t　　為了抗衡國際3大Pay，...
# 28            28    28  家樂福賺回饋攻略技　行動Pay升級儲值錢包\n\n\n\r\n\t　　到家樂福不僅能買到「俗...
# 29            29    29  專訪》悠遊卡轉型推手　陳亭如細說電支\n\n\n\r\n\t　　電子支付已在台遍地萌芽，而身...
# ...          ...   ...                                                ...
# 5564        5564  5564  繳停車費 eTag嘛吔通銀行與eTag合作，除了指定信用卡自動儲值eTag，用來繳納高速公路...
# 5565        5565  5565  瘋世足 餐廳刷卡優惠多全民瘋世足，銀行與各大餐飲業合作推優惠。 本報系資料庫facebook...
# 5566        5566  5566  業者搶發行權…得靠擲筊銀行發行宗教卡有不少趣事。合庫銀行指出，當初想與鹿港天后宮發行聯名卡的...
# 5567        5567  5567  刷卡繳稅 留意授權限制台北國稅局提醒，以信用卡繳納結算申報的民眾，每一申報戶僅能取得一組有效...
# 5568        5568  5568  信用卡搭乘大眾運輸 也有折扣信用卡除了提供市區免費停車優惠外，還有其他像是加油折扣、大眾運輸...
# 5569        5569  5569  善用信用卡優惠 停車更Free市區車位不僅一位難求，停車費用也貴，善於精打細算的車主，不妨可...
# 5570        5570  5570  海外出遊消費 卡好康台北近期飆出37.4度炎熱高溫，代表暑假將至，銀行業者除推出海外刷卡優惠...
# 5571        5571  5571  銀行促刷 滿額送回饋金通常信用卡繳稅沒有紅利點數，但部分銀行為鼓勵信用卡繳稅，推出刷卡繳所得...
# 5572        5572  5572  信用卡繳稅 優惠比一比報稅季節來臨，透過信用卡繳稅 ，不但享有延遲付款好處，還有多家信用卡提...
# 5573        5573  5573  寵愛媽咪 百貨刷卡優惠多迎戰母親節檔期，信用卡發行銀行「促刷」比拚一波接一波，百貨雙雄新光三...
# 5574        5574  5574  球團聯名卡 好康放送球團聯名卡示意圖。 報系資料照facebook中華職棒球季熱鬧開打，喜歡...
# 5575        5575  5575  嚐美食遊南韓 卡好康萬事達卡最新發布的2017下半年「消費者購買傾向調查－旅遊」，日本和韓國...
# 5576        5576  5576  刷卡繳牌照稅 享優惠春假連續假期民眾開車或騎車出遊很開心，別忘了汽機車牌照稅本月開徵，要記得...
# 5577        5577  5577  投保旅綜險 保障更周全清明節連續假期即將來臨，專家提醒，刷信用卡買機票或付團費所附贈的旅平險...
# 5578        5578  5578  海外刷卡 現金回饋大國人海外旅遊蔚為風潮，越來越多銀行推出高現金回饋方案搶客。陽信銀行大方給...
# 5579        5579  5579  Debit卡搶市 大方給利近年來銀行業強打低門檻、有存款就能刷的簽帳Debit金融卡，主打特...
# 5580        5580  5580  信用卡停車優惠 縮水要在市區停車少花錢，可聰明使用信用卡優惠。 (本報系資料庫)facebo...
# 5581        5581  5581  加油、停車、住宿 刷卡也有優惠農曆春節向來是國人最重視的節日，一家人難得團聚，也會找地方春遊...
# 5582        5582  5582  採買年貨 刷卡享好康為搶攻年前民眾採買年貨的百億元商機大餅，各家銀行推出虛、實通路的各項優惠...
# 5583        5583  5583  App 叫車、車主共乘媒合新管道  滴滴出行正式上線！中國最大叫車 App 服務平台滴滴打車...
# 5584        5584  5584  三卡在手 交通費省很大各銀行悠遊聯名卡拚優惠，有信用卡組織祭出每月1日加值，現金回饋最高10...
# 5585        5585  5585  房屋稅逾30日　15%滯納金加強制執行facebook圖文/住展為提醒工作忙碌而忘記繳納房屋...
# 5586        5586  5586  永豐銀行「豐雲房貸」數位平台上線 首創彈性繳款圖擷自永豐銀行。facebook永豐銀行「豐雲...
# 5587        5587  5587  牌照稅下月開徵 車數稅額同增2％2017年使用牌照稅將於4月1日開徵，課稅車輛與稅額皆同步成...
# 5588        5588  5588  Jaguar與殼牌機油合作  推出世界第一個車載付費系統現今的車載系統功能越來越多元與先進，...
# 5589        5589  5589  Join Me App手機定位  幫你找到最近拖吊車價格透明、值得信賴的道路救援服務，現在可...
# 5590        5590  5590  smart攜手台新銀行 為車主打造聯名信用卡台新金控執行長尚瑞強(左)、台灣賓士轎車行銷業務...
# 5591        5591  5591  Gogoro台南門市試營運  15座電池交換站開站電動機車品牌Gogoro宣布台南門市 (台...
# 5592        5592  5592  Gogoro祭好康 學生購車折三千再送月租費Gogoro銷售連九月稱霸電動機車冠軍，六月衝破...
# 5593        5593  5593  刷 MasterCard信用卡就可能收到煩人的汽車廣告你是否也曾在刷完一筆高額信用卡費用後，...
#
#                                   article_vector_matrix  label
# 0     0.0002087556931655854, -0.0005011226749047637,...      7
# 1     -0.00029341760091483593, -0.000209834950510412...     19
# 2     0.0008746232488192618, -0.0006640242645516992,...      7
# 3     0.0002632589603308588, -0.0006318831001408398,...      7
# 4     0.0002618952130433172, -0.000628599664196372, ...      7
# 5     0.00026534072821959853, -0.0006368649774231017...      7
# 6     0.00012652100122068077, -0.0003037579590454697...     10
# 7     -0.00015988782979547977, -0.000830913020763546...      7
# 8     0.00023613832308910787, -0.000566807808354497,...      7
# 9     0.00022709710174240172, -0.0005451262113638222...      7
# 10    0.0002598705468699336, -0.0006237425841391087,...      7
# 11    0.00021872034994885325, -0.0005250319372862577...      7
# 12    -0.00018209261179435998, -0.000939651625230908...      7
# 13    0.0002572191588114947, -0.0006173821166157722,...     13
# 14    0.00012731966853607446, -0.0003056749992538243...     10
# 15    0.00023779523326084018, -0.0005708226235583425...      7
# 16    0.00032638866105116904, -0.0001080733854905702...      3
# 17    0.00011877241195179522, -0.0002851588651537895...     10
# 18    0.0002527071628719568, -0.0006065578781999648,...      7
# 19    0.0002565632457844913, -0.0006158234318718314,...      7
# 20    0.0002477405942045152, -0.0005946430028416216,...      7
# 21    0.00022760964930057526, -0.000546356022823602,...      7
# 22    -0.00023949882597662508, 1.9728577171918005e-0...      7
# 23    0.00021637768077198416, -0.0005193980177864432...     10
# 24    0.0002856281935237348, -0.0006855451501905918,...     16
# 25    0.00025590238510631025, -0.0006142500205896795...      7
# 26    0.00022258682292886078, -0.000534294405952096,...      7
# 27    0.0004715690447483212, -0.0005660200258716941,...      7
# 28    0.00023020866501610726, -0.0005525813321582973...      7
# 29    0.0002688299573492259, -4.105840343981981e-05,...      3
# ...                                                 ...    ...
# 5564  0.0020239120349287987, -0.00036051133065484464...     16
# 5565  -0.00029600595007650554, -0.001118978951126337...      7
# 5566  0.0005243640625849366, -0.001026711193844676, ...      7
# 5567  0.00040695079951547086, 0.002259294269606471, ...      8
# 5568  0.005011911503970623, -0.002473913598805666, 0...      7
# 5569  0.0018348528537899256, -0.002524610375985503, ...      7
# 5570  -0.0012221167562529445, -0.0003013417008332908...      7
# 5571  -0.0003745066933333874, -0.0038593739736825228...      7
# 5572  -3.212874798919074e-05, -0.0010021465132012963...      7
# 5573  -0.00010502051736693829, -0.000956328003667295...      7
# 5574  -0.000647861510515213, -0.0018272802699357271,...      7
# 5575  0.0019443725468590856, -0.003114804858341813, ...      3
# 5576  0.0023627288173884153, -0.002477934816852212, ...     15
# 5577  -0.00044692211668007076, -0.001690971315838396...     10
# 5578  -0.00042662135092541575, -0.001613969565369188...      7
# 5579  -0.0006714491173624992, 1.4347158867167309e-05...      7
# 5580  -0.00029141371487639844, -0.001101589761674404...     15
# 5581  -0.000343004590831697, -0.0011864813277497888,...      7
# 5582  -0.00043653586180880666, -0.001651573460549116...      7
# 5583  -0.0004183389828540385, -0.0015688923886045814...     16
# 5584  0.00017753652355168015, -0.0002162281452910974...      7
# 5585  -0.0010794311529025435, -0.0019588933791965246...      8
# 5586  0.0004945550463162363, 0.00016654268256388605,...      3
# 5587  0.0011402963427826762, -0.00011557101242942736...     10
# 5588  0.0005359649658203125, -0.0005512512288987637,...     16
# 5589  -0.00035877834307029843, -0.000498762878123670...     16
# 5590  -0.00011526169691933319, -0.001135160680860281...      7
# 5591  0.0008152012014761567, -0.0006867680931463838,...     19
# 5592  4.6830497012706473e-05, -0.0001638827670831233...      7
# 5593  -0.0003934263368137181, -0.0014881195966154337...      5
#
# [5594 rows x 5 columns]

# %%
#1.載入LDA分群檔案
group_lists = pd.read_excel(r"C:\Users\Big data\Desktop\class\funcardproject\LDA\LDA_20群_100詞.xlsx")
group_lists
# Out:
#     Unnamed: 0  label                                               word  freq
# 0            0      0  ['我們', '你', '我', '被', '就是', '這個', '民眾', '可以', ...     0
# 1            1      1  ['大陸', '我', '你', '就是', '日本', '現在', '可以', '因為',...     0
# 2            2      2  ['新聞', '活動', '您', '金幣', '該', '好', '按', '優質', '...     0
# 3            3      3  ['贊助', '與', '台灣', '心中', '中獎', '服務', '金融', '網點'...     0
# 4            4      4  ['日', '餐廳', '飯店', '美食', '台北', '吃', '送', '及', '...     0
# 5            5      5  ['旅遊', '台灣', '日', '旅客', '日本', '台北', '機場', '元',...     0
# 6            6      6  ['銀行', '金管會', '資料', '表示', '客戶', '業務', '交易', '或...     0
# 7            7      7  ['回饋', '消費', '優惠', '與', '元', '現金回饋', '最高', '卡'...     0
# 8            8      8  ['繳稅', '蘋果', 'IPHONE', '繳納', '報稅', '申報', '遊戲',...     0
# 9            9      9  ['他', '總統', '我', '他們', '被', '年', '立委', '人', '美...     0
# 10          10     10  ['億元', '今年', '經濟日報', '為', '成長', '金額', '年', '及'...     0
# 11          11     11  ['香港', '廣告', '年', '為', '代言', '運動', '粉絲', '英國',...     0
# 12          12     12  ['盜刷', '警方', '嫌犯', '被', '被害人', '詐騙', '集團', '詐騙...     0
# 13          13     13  ['繳費', '車主', '黃', '罰單', '收費', '萬元', '車輛', '機車'...     0
# 14          14     14  ['他', '她', '被', '我', '發現', '後', '男子', '一名', '陳...     0
# 15          15     15  ['銀行', '刷卡', '民眾', '消費', '優惠', '卡', '元', '可以',...     0
# 16          16     16  ['手機', '支付', '使用', '行動支付', 'APP', '服務', '民眾', ...     0
# 17          17     17  ['元', '發票', '消費者', '違約金', '消基會', '油價', '業者', '...     0
# 18          18     18  ['加油', '加油站', '計程車', '司機', '乘客', '自助', '駕駛', '...     0
# 19          19     19  ['美國', '美元', '市場', '經濟', '全球', '投資', '年', '億',...     0

# %%
#2.載入bin檔
wv_from_bin = KeyedVectors.load_word2vec_format(datapath(r'C:\Users\Big data\Desktop\class\funcardproject\word2vec_model\news\測試100win20cbow1.bin'), binary=True)

# %% [markdown]
# # 測試區

# %%
#餘弦相似度+lDA
input_words= input()
input_vector_matrix =請輸入文字(input_words)
label= get_label(input_words)
group_articles = group_article(label)
articles_matrix =[get_article_matrix(group_articles,i) for i in range(len(group_articles))]
餘閒相似度找文章(input_words)
# Out:
# 加油
# ['加油']
#
# 這幾個字的平均向量是:
# [[-0.15345654 -0.6238221  -1.0769999  -0.61866635  0.0209231  -0.9605614
#   -1.2642494  -0.37164733  0.26911297 -0.4010686  -0.10194021  0.2757209
#   -0.2983463  -0.4311678   0.1817613  -0.18699431 -0.08383089  0.48837778
#   -0.12779827 -0.6869953   0.00196366 -0.5427975   1.1391596   0.2994893
#    0.01698456 -0.37213096  1.0139923  -0.05733864  1.1699623  -0.32728717
#   -0.667234    0.10526878 -0.18875241 -1.4041635  -0.6491697   0.3759047
#   -0.23699889  0.68731207  0.16504571 -0.36506385 -0.412564    0.17019798
#   -0.05354222  0.17962354  0.08538968  1.0042043  -1.4159727  -0.05890266
#    0.08990184  0.37809867  0.06680181  0.35402364 -0.29187325 -0.10760435
#   -0.12110583 -0.6015291   0.10847687  0.29635608 -0.5030992  -0.6891917
#   -0.76386946 -0.2610425   0.21106254 -0.59249175 -0.41311646  0.25119853
#    0.44777417  0.54763895  0.3935621  -1.0098442  -0.14657429 -0.04532123
#   -0.3121821   0.31519026 -0.02617069 -0.25548717  0.22849427  0.7513851
#   -0.45890737 -0.7644684   0.07866499 -0.5607425  -0.06479231 -0.04697144
#    0.24642408 -0.22152819 -0.28822067  0.32114998 -0.42990112 -0.43356368
#    0.53237224 -0.7569827   0.12093274  0.6126595  -1.1049641   0.59498394
#   -0.01730726 -0.60461557 -0.19862665  0.00499046]]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 與第 18 群的第 18 篇新聞最相似
# 文章內文為:
#
#  ------------------------------------------------------------
#  〈獨家〉自助加油試身「手」　每公升2元省很大
# 自助加油降幅相對大了些，但受不同信用卡影響，折扣也有高低差別，至於人工加油，50公升油箱汽車用信用卡5%現金回饋，搭配指定加油站，每公升降1.7元優惠，也能省下破百元，但降幅還是沒有自助加油來的低，開車族想省荷包，還是得先習慣自己加油。

# %%
#餘弦相似度
input_words= input()
input_vector_matrix =請輸入文字(input_words)
餘閒相似度找文章(input_words)
# Out:
# 玉山
# ['玉山']
#
# 這幾個字的平均向量是:
# [[ 0.19610208 -0.563665   -0.3372065  -0.5663267   0.10419251 -0.03174496
#   -0.57335347 -0.01868376 -0.77252775 -0.3306109   0.44495112  0.50069845
#   -0.19555637  0.08804778 -0.7298876  -0.24601893 -0.04557158 -0.38264757
#   -0.18670572 -0.48187992  0.4048067  -0.17634086  0.07316504 -0.4861287
#   -0.5141417   0.6257923   0.61300194  0.27603537 -0.15095751  0.04430315
#    0.12776838 -0.11363579 -0.1937178  -0.04849094 -1.1038033  -0.16659811
#    0.3701372   0.95391536 -0.35162738 -0.6978629   0.1354421   0.17245938
#   -0.27713624 -0.29105332  0.42139494 -0.44791517 -0.43316543 -0.51872057
#   -0.32615614  0.17171097  0.01827458 -0.25880343  0.50627005 -0.06921496
#    0.5086911  -0.49112234 -0.09658755  0.01427571 -0.7565906  -0.39970285
#    0.02148487 -0.17707984 -0.90400654  0.42158422 -0.02072658  0.9841369
#    0.6100574  -0.5122336  -0.73656815 -0.5097141  -0.16665676  0.1635552
#   -0.22809388  0.25000995 -0.2141154  -0.8958415  -0.07857244  0.4800984
#    0.4884535  -0.4106217  -0.3088947   0.03121278 -1.3214395   0.6111621
#    0.4182697   0.11762522  0.15772997  0.08272251 -0.3095944  -0.60688895
#    0.23399884 -0.37150428  0.3042093   0.4811323  -0.08331485  0.60731685
#   -0.17062674 -0.02142499 -0.67650694  0.10243874]]
# 第 171 篇新聞最相似
# 文章內文為:
#
#  ------------------------------------------------------------
#  ISICDEBIT卡學生專屬留遊學現金回饋到海外留學遊學的青年學子將有更便利更優惠的金融服務永豐銀行今日發行永豐國際學生證DEBIT卡只要是學生就能申請享有國際學生證全球超過萬項優惠海外消費現金回饋高達首年發卡目標為萬張根據萬事達卡調查台灣父母送子女出國與日俱增比例從年的上升至年的為滿足海外學子金融需求永豐銀行與康文文教基金會萬事達卡合作推出國際學生證DEBIT卡學生至康文辦事處或網站取得國際學生證ISIC資格就能到忠孝新竹興大東台南高雄等永豐分行開戶辦理國際學生證DEBIT卡享有國際學生證全球個國家超過萬項優惠永豐國際學生證DEBIT卡不僅是學生證與提款卡於國內消費享現金回饋以及每月次免費跨行提款轉帳在海外消費的現金回饋更高達每月還補貼國外提款手續費最高元新台幣以單次手續費約元計算相當於每月有次提款免手續費從事國外旅遊購買飛機火車或巴士車票還有萬元新台幣旅遊平安險保障異國求學的學子永豐銀行表示以美國為例持國際學生證能以折購買紐約市通行證CITYPASS奧蘭多環球影城門票折大都會博物館與MOMA紐約現代美術館只要美元美元在其他國家如丹麥購買APPLE商品享折價澳洲更有麥當勞與肯德基指定餐點買送台灣每年發證數高達萬張永豐結合金融卡功能加入現金回饋好康預期首年就能發出萬張即日起申辦卡片前名能省下國際學生證申辦費元新台幣發卡次月底前一般消費累積滿元新台幣加贈元刷卡金開通悠遊卡功能並自動加值成功再送元刷卡金首月加總能拿到元優惠永豐銀行近個月動作不斷陸續發行三井OUTLET台中港聯名卡SPORT運動卡及國際學生證DEBIT卡具強烈企圖心截至月底為止永豐銀行流通卡數逼近萬張有效卡數超過萬張卡量名列第名與排名第的聯邦銀行萬流通卡萬有效卡差距不大永豐銀行指出在新發卡片的加持下明年可望超車聯邦銀行

# %% [markdown]
# # 根據分群選向量

# %%
def group_article(label):
    group_articles=pd.DataFrame(columns=['Unnamed: 0','No.','content','article_vector_matrix','label'])
    cc=0
    for n,i in enumerate(articles['label']):
        if i == label:
            group_articles.loc[cc]=list(articles.loc[n])
            cc+=1
    return group_articles

# %%
def get_label(input_words):
    group_lists["freq"]=0
    for n,group in enumerate(group_lists["word"]):
        for input_word in input_words:
            if input_word in group:
                group_lists["freq"][n]+=1
    label = np.where(group_lists["freq"]==np.max(group_lists["freq"]))
    label=label[0][0]
    return label

# %%
#4.獲取輸入詞的平均向量
def get_article_avgvector(wordlist):
    #取每篇文章平均向量
    # x=np.matrix(wv_from_bin[word])安安?
    len_wordlist=0
    input_avgvector_matrix=0
    for word in wordlist:

        try:
            x=np.matrix(wv_from_bin[word])
            input_avgvector_matrix+=x
            len_wordlist+=1

        except:
            pass
    if type(input_avgvector_matrix)==int:
        input_avgvector_matrix = articles_matrix[1]
    else:
        input_avgvector_matrix = input_avgvector_matrix/len_wordlist
    
 
      
    #若沒有輸入文章或輸入的詞不在bin檔則回傳第0篇文章向量

    
     
    return(input_avgvector_matrix)

# %%
x=np.matrix(wv_from_bin["旅遊"])
y=np.matrix(wv_from_bin["加油"])
input_avgvector_matrix=0
input_avgvector_matrix+=x
input_avgvector_matrix+=y
input_avgvector_matrix
# Out:
# matrix([[ 0.49321005, -0.97627735, -1.4002988 , -0.68763477, -0.1221542 ,
#          -0.5081506 , -1.8594931 , -0.61623746,  0.24533285, -0.50148046,
#          -0.57171524,  0.11776888, -0.07833362, -1.0480946 , -0.02709624,
#          -0.6206844 , -0.09482106,  0.6255164 , -0.9778987 , -0.76802504,
#          -0.08358138, -0.09517649,  1.5977589 ,  0.35336128, -0.48482433,
#           0.0540897 ,  0.91026616, -0.3784378 ,  1.6129799 , -0.3451628 ,
#          -1.5321958 ,  0.13388553,  0.05983865, -1.3810012 , -0.81214154,
#           0.19814089, -0.17143549,  0.8975501 , -0.08294594, -0.7686179 ,
#          -0.84542733,  0.02836706, -0.22351918, -0.0919289 ,  0.6135563 ,
#           1.719913  , -1.4062992 ,  0.61917096,  0.41225258,  0.3907897 ,
#           0.16261263,  0.84341156, -0.21983007, -0.19169547, -0.39086354,
#          -1.2234123 , -0.7592441 ,  0.10992469, -0.70064735, -0.8791137 ,
#          -1.1320727 , -0.4950929 ,  0.19753097, -0.47997445,  0.27035797,
#           0.5783057 ,  0.5555821 ,  0.3693077 ,  0.2578745 , -1.0639296 ,
#           0.15000439, -0.47604662, -0.14871505,  0.33519515,  0.5018694 ,
#          -0.5255309 ,  0.34885353,  0.7911588 , -0.7902082 , -0.00725085,
#          -0.1160955 , -0.7060676 , -0.8587929 ,  0.15730458,  0.30203998,
#          -0.09920797, -0.25961873,  0.362034  , -0.597182  , -0.8793932 ,
#           0.4543312 , -0.70007396, -0.2694512 ,  0.03651327, -1.9549129 ,
#          -0.06064856, -0.03636876, -0.4118322 , -0.3418204 , -0.32556272]],
#        dtype=float32)

# %%
#3.輸入文字
def 請輸入文字(input_words):
    #隨意輸入文字
    #轉DataFrame
    # input_words=pd.DataFrame(input_words,columns=['content'])
    #斷詞
    wordlist=jieba.lcut(input_words,cut_all=False)
    # df1=斷詞(input_words)
    #清乾淨
    # news = 整理(cut)
    # 吐出來
    # output_words = input_words['seg'][0]
    # output_words = output_words.split(' ')
    print(wordlist)
    input_vector_matrix = get_article_avgvector(wordlist)
    print()
    print("這幾個字的平均向量是:")
    print(input_vector_matrix)
    return(input_vector_matrix)
    return(wordlist)

# %%
#3.輸入文字
def 請輸入文字(input_words):
    #隨意輸入文字
    #轉DataFrame
    input_words=pd.DataFrame(input_words,columns=['content'])
    #斷詞
#     wordlist=jieba.lcut(input_words,cut_all=False)
    df1=斷詞(input_words)
    #清乾淨
    input_words = 整理(cut)
    # 吐出來
    output_words = input_words['seg'][0]
    output_words = output_words.split(' ')
    print(output_words)
    input_vector_matrix = get_article_avgvector(output_words)
    print()
    print("這幾個字的平均向量是:")
    print(input_vector_matrix)
    return(input_vector_matrix)
    return(wordlist)

# %%
#5.餘弦相似度
def cos_sim(vector_a, vector_b):
    """
    计算两个向量之间的余弦相似度
    :param vector_a: 向量 a 
    :param vector_b: 向量 b
    :return: sim
    """
    vector_a = np.mat(vector_a)
    vector_b = np.mat(vector_b)
    num = float(vector_a * vector_b.T)
    denom = np.linalg.norm(vector_a) * np.linalg.norm(vector_b)
    cos = num / denom
    sim = 0.5 + 0.5 * cos
    return sim

# %%
#撈出存在excel的向量轉為matrix
def get_article_matrix(article,i):
    aa = article.loc[:,["article_vector_matrix"]][i:i+1]
    #轉ARRAY再轉list
    b = np.array(aa)
    b=b[0].tolist()#list
    # 切
    c = str(b[0]).split(',')
    article_matrix = np.mat(c).astype(float)
    return(article_matrix)

# %%
#比對
def 餘閒相似度找文章(input_words):
    articles_matrix_list=[]
    for b in range(len(group_articles)):
        結果=cos_sim(input_vector_matrix,articles_matrix[b])
        articles_matrix_list.append(結果)
#     print("第",articles_matrix_list.index(max(articles_matrix_list)),"篇新聞最相似")
    print("與第",label,"群的第",articles_matrix_list.index(max(articles_matrix_list)),"篇新聞最相似")
    哭喔 = articles_matrix_list.index(max(articles_matrix_list))
    print("文章內文為:","\n","\n","------------------------------------------------------------","\n",np.array(group_articles[哭喔:哭喔+1]['content'])[0])

# %%
# 斷詞套件
def 斷詞(news):
    df1=news
    df1['seg']=None
    df1['word_freq']=None
    n=len(news)
    alltext=[]
    stopset=set()
    stop2=['/n','']
    with open('C:\\Users\\Big data\\Desktop\\字詞貼標\\DB104-master\\stop.txt','r',encoding='ISO-8859-1') as s:
        for line in s:
            stopset.add(line.strip('\n'))
    jieba.load_userdict('C:\\Users\\Big data\\Desktop\\字詞貼標\\DB104-master\\userdict.txt')
    for i in range(n):
        seg=''
        wf={}
        text= str(df1.loc[i]['content'])
        cut=jieba.cut(text,cut_all=False)
        for j in cut:
            if j not in stopset:
                seg +=j+' '
                seg = seg.replace("\n",'')
        df1['seg'][i]=seg
        for w in seg.split(' '):
            if w not in wf:
                wf[w]=1
            else:
                wf[w]+=1
        word_list=[(k,wf[k]) for k in wf if k not in stop2 ]
        word_list.sort(key=lambda a :a[1],reverse=True)
        df1['word_freq'][i]=word_list
    return(df1)



# 斷詞整理(去除標點符號)
def 整理(df1):
    datanews = df1["seg"]
    # 轉list
    train_data = np.array(datanews)#np.ndarray()
    datanews=train_data.tolist()#list
    df1=''
    for datanew in datanews:
        df1+=str(datanew)+'\n'
    df1=df1.replace('[','').replace('\'','').replace('「 ','').replace('」 ','').replace('」 ','').replace('、 ','').replace('： ','')
    df1=df1.replace('《 ','').replace('》 ','').replace('） ','').replace('( ','').replace('／ ','').replace('， ','')
    df1=df1.replace('╱ ','').replace('！ ','').replace('？ ','').replace('（ ','').replace('。 ','').replace('； ','').replace('… ','')
    df1=df1.replace(']','').replace(' :','').replace('\u3000','').replace('\n','')
    df2=df1
    for i in range(len(df2)):
        df1=' '.join(df2.split())
    return(df1)
